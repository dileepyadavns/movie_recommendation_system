# %%
import pandas as pd
import numpy as np

# %%
import requests
import bs4 as bs
import urllib.request

# %%
link="https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
md=pd.read_csv('main_data.csv')

# %%
md
# Out:
#                                            director_name  \
# 0                                          John Lasseter
# 1                                           Joe Johnston
# 2                                          Howard Deutch
# 3                                        Forest Whitaker
# 4                                          Charles Shyer
# ...                                                  ...
# 37426                                     Matthew Vaughn
# 37427                                          Joel Coen
# 37428                                  Denzel Washington
# 37429                                     Erwin brothers
# 37430  Apichatpong Weerasethakul (director/acreenplay...
#
#                                             actor_1_name       actor_2_name  \
# 0                                              Tom Hanks          Tim Allen
# 1                                         Robin Williams      Jonathan Hyde
# 2                                         Walter Matthau        Jack Lemmon
# 3                                        Whitney Houston     Angela Bassett
# 4                                           Steve Martin       Diane Keaton
# ...                                                  ...                ...
# 37426                                      Ralph Fiennes     Gemma Arterton
# 37427                                  Denzel Washington  Frances McDormand
# 37428                                  Michael B. Jordan       Chanté Adams
# 37429                                       Zachary Levi        Anna Paquin
# 37430  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#           actor_3_name                                 genres  \
# 0          Don Rickles                Animation Comedy Family
# 1        Kirsten Dunst               Adventure Fantasy Family
# 2          Ann-Margret                         Romance Comedy
# 3       Loretta Devine                   Comedy Drama Romance
# 4         Martin Short                                 Comedy
# ...                ...                                    ...
# 37426       Rhys Ifans  Action Adventure Thriller War Mystery
# 37427    Bertie Carvel                              Drama War
# 37428  Jalon Christian                          Drama Romance
# 37429     Dennis Quaid                                  Drama
# 37430   Jeanne Balibar          Drama Science Fiction Mystery
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 37426               the king's man
# 37427       the tragedy of macbeth
# 37428         a journal for jordan
# 37429            american underdog
# 37430                      memoria
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37426  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 37427  Denzel Washington Frances McDormand Bertie Car...
# 37428  Michael B. Jordan Chanté Adams Jalon Christian...
# 37429  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 37430  Apichatpong Weerasethakul (director/acreenplay...
#
# [37431 rows x 7 columns]

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# /tmp/ipykernel_12307/903390518.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                              Title  \
# 0     JANUARY        7.0                            The 355
# 1     JANUARY        7.0           The Legend of La Llorona
# 2     JANUARY        7.0                       The Commando
# 3     JANUARY       14.0                             Scream
# 4     JANUARY       14.0  Hotel Transylvania: Transformania
# ..        ...        ...                                ...
# 249  DECEMBER       21.0        I Wanna Dance with Somebody
# 250  DECEMBER       21.0                            Wildcat
# 251  DECEMBER       25.0                            Babylon
# 252  DECEMBER        NaN                                NaN
# 253  DECEMBER        NaN                                NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                                          Saban Films
# 2                                          Saban Films
# 3            Paramount Pictures / Spyglass Media Group
# 4    Amazon Studios / Columbia Pictures / Sony Pict...
# ..                                                 ...
# 249               TriStar Pictures / Black Label Media
# 250                                     Amazon Studios
# 251                                 Paramount Pictures
# 252                                                NaN
# 253                                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 249  Kasi Lemmons (director); Anthony McCarten (scr...
# 250             Melissa Lesh, Trevor Frost (directors)
# 251  Damien Chazelle (director/screenplay); Brad Pi...
# 252                                                NaN
# 253                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 249   [54]
# 250  [168]
# 251  [212]
# 252    NaN
# 253    NaN
#
# [254 rows x 7 columns]

# %%
df_2022 = df[['Title','Cast and crew']]
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 249        I Wanna Dance with Somebody
# 250                            Wildcat
# 251                            Babylon
# 252                                NaN
# 253                                NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 249  Kasi Lemmons (director); Anthony McCarten (scr...
# 250             Melissa Lesh, Trevor Frost (directors)
# 251  Damien Chazelle (director/screenplay); Brad Pi...
# 252                                                NaN
# 253                                                NaN
#
# [254 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# /tmp/ipykernel_12307/3153303190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 249        I Wanna Dance with Somebody
# 250                            Wildcat
# 251                            Babylon
# 252                                NaN
# 253                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 249  Kasi Lemmons (director); Anthony McCarten (scr...
# 250             Melissa Lesh, Trevor Frost (directors)
# 251  Damien Chazelle (director/screenplay); Brad Pi...
# 252                                                NaN
# 253                                                NaN
#
#                                         genres
# 0                              Action Thriller
# 1                             Family Animation
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 249                              Drama History
# 250                         Drama Thriller War
# 251  Action Adventure Science Fiction Thriller
# 252                                     Comedy
# 253                                     Comedy
#
# [254 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /tmp/ipykernel_12307/3644665622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# /tmp/ipykernel_12307/2887556167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# /tmp/ipykernel_12307/3311399709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 249        I Wanna Dance with Somebody
# 250                            Wildcat
# 251                            Babylon
# 252                                NaN
# 253                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 249  Kasi Lemmons (director); Anthony McCarten (scr...
# 250             Melissa Lesh, Trevor Frost (directors)
# 251  Damien Chazelle (director/screenplay); Brad Pi...
# 252                                                NaN
# 253                                                NaN
#
#                                         genres  \
# 0                              Action Thriller
# 1                             Family Animation
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 249                              Drama History
# 250                         Drama Thriller War
# 251  Action Adventure Science Fiction Thriller
# 252                                     Comedy
# 253                                     Comedy
#
#                             director_name      actor_1_name  \
# 0                           Simon Kinberg  Jessica Chastain
# 1                  Patricia Harris Seeley     Autumn Reeser
# 2                              Asif Akbar     Mickey Rourke
# 3    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska, Derek Drymon      Andy Samberg
# ..                                    ...               ...
# 249                          Kasi Lemmons       Naomi Ackie
# 250            Melissa Lesh, Trevor Frost      Melissa Lesh
# 251                       Damien Chazelle         Brad Pitt
# 252                                   nan               nan
# 253                                   nan               nan
#
#                  actor_2_name   actor_3_name
# 0              Lupita Nyong'o  Penélope Cruz
# 1                Antonio Cupo    Danny Trejo
# 2           Michael Jai White            NaN
# 3               Mason Gooding   Jenna Ortega
# 4                Selena Gomez   Kathryn Hahn
# ..                        ...            ...
# 249            Ashton Sanders  Stanley Tucci
# 250  Trevor Frost (directors)            NaN
# 251             Margot Robbie  Tobey Maguire
# 252                       NaN            NaN
# 253                       NaN            NaN
#
# [254 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df22
# Out:
#                             director_name      actor_1_name  \
# 0                           Simon Kinberg  Jessica Chastain
# 1                  Patricia Harris Seeley     Autumn Reeser
# 2                              Asif Akbar     Mickey Rourke
# 3    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera
# 4           Jennifer Kluska, Derek Drymon      Andy Samberg
# ..                                    ...               ...
# 249                          Kasi Lemmons       Naomi Ackie
# 250            Melissa Lesh, Trevor Frost      Melissa Lesh
# 251                       Damien Chazelle         Brad Pitt
# 252                                   nan               nan
# 253                                   nan               nan
#
#                  actor_2_name   actor_3_name  \
# 0              Lupita Nyong'o  Penélope Cruz
# 1                Antonio Cupo    Danny Trejo
# 2           Michael Jai White            NaN
# 3               Mason Gooding   Jenna Ortega
# 4                Selena Gomez   Kathryn Hahn
# ..                        ...            ...
# 249            Ashton Sanders  Stanley Tucci
# 250  Trevor Frost (directors)            NaN
# 251             Margot Robbie  Tobey Maguire
# 252                       NaN            NaN
# 253                       NaN            NaN
#
#                                         genres  \
# 0                              Action Thriller
# 1                             Family Animation
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 249                              Drama History
# 250                         Drama Thriller War
# 251  Action Adventure Science Fiction Thriller
# 252                                     Comedy
# 253                                     Comedy
#
#                            movie_title
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 249        I Wanna Dance with Somebody
# 250                            Wildcat
# 251                            Babylon
# 252                                NaN
# 253                                NaN
#
# [254 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      6
# actor_3_name     22
# genres            1
# movie_title       2
# comb             23
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# /tmp/ipykernel_12307/2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# 5                             Luis Prieto
# ..                                    ...
# 246                       Matthew Warchus
# 247                     David F. Sandberg
# 248                         Joel Crawford
# 249                          Kasi Lemmons
# 251                       Damien Chazelle
#
#                                    actor_1_name    actor_2_name  \
# 0                              Jessica Chastain  Lupita Nyong'o
# 1                                 Autumn Reeser    Antonio Cupo
# 3                               Melissa Barrera   Mason Gooding
# 4                                  Andy Samberg    Selena Gomez
# 5                              Cameron Monaghan    Frank Grillo
# ..                                          ...             ...
# 246                                 Alisha Weir   Lashana Lynch
# 247                                Zachary Levi     Asher Angel
# 248  Joel Crawford (director); Antonio Banderas     Salma Hayek
# 249                                 Naomi Ackie  Ashton Sanders
# 251                                   Brad Pitt   Margot Robbie
#
#            actor_3_name                                     genres  \
# 0         Penélope Cruz                            Action Thriller
# 1           Danny Trejo                           Family Animation
# 3          Jenna Ortega                    Horror Mystery Thriller
# 4          Kathryn Hahn  Animation Family Fantasy Comedy Adventure
# 5            Lilly Krug                                   Thriller
# ..                  ...                                        ...
# 246  Andrea Riseborough                      Comedy Family Fantasy
# 247   Jack Dylan Grazer                      Comedy Action Fantasy
# 248      Harvey Guillén  Animation Adventure Comedy Family Fantasy
# 249       Stanley Tucci                              Drama History
# 251       Tobey Maguire  Action Adventure Science Fiction Thriller
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 3                               scream
# 4    hotel transylvania: transformania
# 5                            shattered
# ..                                 ...
# 246                            matilda
# 247           shazam! fury of the gods
# 248       puss in boots: the last wish
# 249        i wanna dance with somebody
# 251                            babylon
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 5    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 246  Alisha Weir Lashana Lynch Andrea Riseborough M...
# 247  Zachary Levi Asher Angel Jack Dylan Grazer Dav...
# 248  Joel Crawford (director); Antonio Banderas Sal...
# 249  Naomi Ackie Ashton Sanders Stanley Tucci Kasi ...
# 251  Brad Pitt Margot Robbie Tobey Maguire Damien C...
#
# [231 rows x 7 columns]

# %%
new_df22.to_csv('main_data.csv',mode="a",index=False)

# %%
md=pd.read_csv("main_data.csv")

# %%
md
# Out:
#            director_name                                actor_1_name  \
# 0          John Lasseter                                   Tom Hanks
# 1           Joe Johnston                              Robin Williams
# 2          Howard Deutch                              Walter Matthau
# 3        Forest Whitaker                             Whitney Houston
# 4          Charles Shyer                                Steve Martin
# ...                  ...                                         ...
# 37658    Matthew Warchus                                 Alisha Weir
# 37659  David F. Sandberg                                Zachary Levi
# 37660      Joel Crawford  Joel Crawford (director); Antonio Banderas
# 37661       Kasi Lemmons                                 Naomi Ackie
# 37662    Damien Chazelle                                   Brad Pitt
#
#          actor_2_name        actor_3_name  \
# 0           Tim Allen         Don Rickles
# 1       Jonathan Hyde       Kirsten Dunst
# 2         Jack Lemmon         Ann-Margret
# 3      Angela Bassett      Loretta Devine
# 4        Diane Keaton        Martin Short
# ...               ...                 ...
# 37658   Lashana Lynch  Andrea Riseborough
# 37659     Asher Angel   Jack Dylan Grazer
# 37660     Salma Hayek      Harvey Guillén
# 37661  Ashton Sanders       Stanley Tucci
# 37662   Margot Robbie       Tobey Maguire
#
#                                           genres  \
# 0                        Animation Comedy Family
# 1                       Adventure Fantasy Family
# 2                                 Romance Comedy
# 3                           Comedy Drama Romance
# 4                                         Comedy
# ...                                          ...
# 37658                      Comedy Family Fantasy
# 37659                      Comedy Action Fantasy
# 37660  Animation Adventure Comedy Family Fantasy
# 37661                              Drama History
# 37662  Action Adventure Science Fiction Thriller
#
#                         movie_title  \
# 0                         toy story
# 1                           jumanji
# 2                  grumpier old men
# 3                 waiting to exhale
# 4       father of the bride part ii
# ...                             ...
# 37658                       matilda
# 37659      shazam! fury of the gods
# 37660  puss in boots: the last wish
# 37661   i wanna dance with somebody
# 37662                       babylon
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37658  Alisha Weir Lashana Lynch Andrea Riseborough M...
# 37659  Zachary Levi Asher Angel Jack Dylan Grazer Dav...
# 37660  Joel Crawford (director); Antonio Banderas Sal...
# 37661  Naomi Ackie Ashton Sanders Stanley Tucci Kasi ...
# 37662  Brad Pitt Margot Robbie Tobey Maguire Damien C...
#
# [37663 rows x 7 columns]
